# %%
from tax_pull import import_data
from best_classifier import do_classification
from test_multi_classification import binary_classification_regression

# %%
SamplePopulation_CandyBeverages, Albertsons_CandyBeverages, Albertsons_HealthBeauty = import_data.get_df()

# %%
binary_classification_regression.excecute_regression(Albertsons_CandyBeverages["Product Description"], Albertsons_CandyBeverages["Category Description"])
# Out:
# /Users/tonderaimadamba/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# ...
# LogisticRegression
# ****Results****
# Accuracy: 87.0103%
# ...
# LinearSVC
# ****Results****
# Accuracy: 95.0515%
# ...
# KNeighborsClassifier
# ****Results****
# Accuracy: 84.7423%
# ...
# SVC
# ****Results****
# Accuracy: 91.9588%
# ...
# DecisionTreeClassifier
# ****Results****
# Accuracy: 86.1856%
# ...
# RandomForestClassifier
# ****Results****
# Accuracy: 87.0103%
# ...

# %%
do_classification.text_classification(Albertsons_CandyBeverages["Product Description"], Albertsons_CandyBeverages["Category Description"])
# Out:
# (3878    Beverages containing at least 5% but less than...
#  1684    Milk or milk substitutes, or drinks with bases...
#  1044     All carbonated, non-alcoholic beverages that ...
#  4807    Powdered drink mixes and frozen concentrates t...
#  1538                         Tea leaves or tea bags/pods.
#                                ...
#  3254    Unsweetened water that is carbonated artificia...
#  586     A preparation of sugar, honey, or other natura...
#  3128    All non-carbonated, non-alcoholic beverages th...
#  151     A preparation of sugar, honey, or other natura...
#  1870                         Tea leaves or tea bags/pods.
#  Name: Category Description, Length: 485, dtype: object,
# ...
